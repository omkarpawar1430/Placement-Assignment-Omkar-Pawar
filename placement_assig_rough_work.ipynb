# %%
my_string = 'write write write all the number from from from 1 to 100'

def frequent_word(string):
    """ Returns most frequently occurring word from a string."""

    list_of_substrings = string.split()
    checked_words = {}
    most_frequent_occur = 0

    for i in list_of_substrings:
        if i in checked_words:
            continue
        else:
            #print(i, list_of_substrings.count(i))
            occur = list_of_substrings.count(i)
            checked_words[i]= occur
            if occur > most_frequent_occur:
                most_frequent_occur = occur
    
    #print(most_frequent_occur)    
    print(checked_words)
    list_most_frequent_occurred_words = []
    for k, v in checked_words.items():
        if v == most_frequent_occur:
            list_most_frequent_occurred_words.append(k)
    # print(list_most_frequent_occurred_words)
    
    max_len = 0
    for i in list_most_frequent_occurred_words:
        if len(i) > max_len:
            max_len = len(i)
    return(max_len)
frequent_word(my_string)

# %%
def find_highest_frequency_length(string):
    word_list = string.split()
    word_count = {}

    for word in word_list:
        word_count[word] = word_count.get(word, 0) + 1

    max_frequency = max(word_count.values())
    highest_frequency_words = [word for word, count in word_count.items() if count == max_frequency]
    highest_frequency_word_length = len(max(highest_frequency_words, key=len))

    return highest_frequency_word_length

# Example usage:
string = "write write write all the number from from from 1 to 100"
output = find_highest_frequency_length(string)
print(output)
# Out:
# 5

# %% [markdown]
# -----------

# %%
link_to_data = 'https://raw.githubusercontent.com/Biuni/PokemonGO-Pokedex/master/pokedex.json'

# %%
import pandas as pd
import requests

# Step 1: Download JSON data
url = link_to_data
response = requests.get(url)
data = response.json()

# %%
data["pokemon"][0]
# Out:
# {'id': 1,
#  'num': '001',
#  'name': 'Bulbasaur',
#  'img': 'http://www.serebii.net/pokemongo/pokemon/001.png',
#  'type': ['Grass', 'Poison'],
#  'height': '0.71 m',
#  'weight': '6.9 kg',
#  'candy': 'Bulbasaur Candy',
#  'candy_count': 25,
#  'egg': '2 km',
#  'spawn_chance': 0.69,
#  'avg_spawns': 69,
#  'spawn_time': '20:00',
#  'multipliers': [1.58],
#  'weaknesses': ['Fire', 'Ice', 'Flying', 'Psychic'],
#  'next_evolution': [{'num': '002', 'name': 'Ivysaur'},
#   {'num': '003', 'name': 'Venusaur'}]}

# %%
number_of_pokemons = len(data["pokemon"])
number_of_pokemons
# Out:
# 151

# %%
columns = list(data["pokemon"][0].keys())
columns
# Out:
# ['id',
#  'num',
#  'name',
#  'img',
#  'type',
#  'height',
#  'weight',
#  'candy',
#  'candy_count',
#  'egg',
#  'spawn_chance',
#  'avg_spawns',
#  'spawn_time',
#  'multipliers',
#  'weaknesses',
#  'next_evolution']

# %%
file_path = "pokemon.csv"

# %%
def add_entry(line):
    for i in line:
        with open(file_path, "a") as file:
            file.write(f"{str(i)}, ")
    with open(file_path, "a") as file:
        file.write("\n")

add_entry(columns)

# %%
for i in range(0, number_of_pokemons):
    for val in data["pokemon"][i].values():
        with open(file_path, "a") as file:
            file.write(f"{str(val)}, ")
    with open(file_path, "a") as file:
        file.write("\n")

# %%
find_highest_frequency_length("I I I am not not done yet.")
# Out:
# 1

# %%
df = pd.read_csv("/home/omkar/Omkar Pawar/Data Science/Placement Assignment Omkar Pawar/pokemon.csv")
df
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 df = pd.read_csv("/home/omkar/Omkar Pawar/Data Science/Placement Assignment Omkar Pawar/pokemon.csv")
#       2 df
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import json
import pandas as pd 

Link ="https://raw.githubusercontent.com/Biuni/PokemonGO-Pokedex/master/pokedex.json"

data = pd.read_json(Link,orient="columns")
dict= data['pokemon']
# pd.set_option("display.max_columns",None)

tabled_json = pd.json_normalize(dict2)
tabled_json.head()
# Out:
#    id  num        name                                               img
# 0   1  001   Bulbasaur  http://www.serebii.net/pokemongo/pokemon/001.png  \
# 1   2  002     Ivysaur  http://www.serebii.net/pokemongo/pokemon/002.png
# 2   3  003    Venusaur  http://www.serebii.net/pokemongo/pokemon/003.png
# 3   4  004  Charmander  http://www.serebii.net/pokemongo/pokemon/004.png
# 4   5  005  Charmeleon  http://www.serebii.net/pokemongo/pokemon/005.png
#
#               type  height    weight             candy  candy_count
# 0  [Grass, Poison]  0.71 m    6.9 kg   Bulbasaur Candy         25.0  \
# 1  [Grass, Poison]  0.99 m   13.0 kg   Bulbasaur Candy        100.0
# 2  [Grass, Poison]  2.01 m  100.0 kg   Bulbasaur Candy          NaN
# 3           [Fire]  0.61 m    8.5 kg  Charmander Candy         25.0
# 4           [Fire]  1.09 m   19.0 kg  Charmander Candy        100.0
#
#            egg  spawn_chance  avg_spawns spawn_time multipliers
# ...

# %%
tabled_json.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151 entries, 0 to 150
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              151 non-null    int64
#  1   num             151 non-null    object
#  2   name            151 non-null    object
#  3   img             151 non-null    object
#  4   type            151 non-null    object
#  5   height          151 non-null    object
#  6   weight          151 non-null    object
#  7   candy           151 non-null    object
#  8   candy_count     70 non-null     float64
#  9   egg             151 non-null    object
#  10  spawn_chance    151 non-null    float64
#  11  avg_spawns      151 non-null    float64
#  12  spawn_time      151 non-null    object
#  13  multipliers     70 non-null     object
#  14  weaknesses      151 non-null    object
#  15  next_evolution  70 non-null     object
#  16  prev_evolution  72 non-null     object
# ...

# %%
unique_values_in_type = []

# %%
tabled_json["type"].head()
# Out:
# 0    [Grass, Poison]
# 1    [Grass, Poison]
# 2    [Grass, Poison]
# 3             [Fire]
# 4             [Fire]
# Name: type, dtype: object

# %%
df = tabled_json

# %%
df.columns
# Out:
# Index(['id', 'num', 'name', 'img', 'type', 'height', 'weight', 'candy',
#        'candy_count', 'egg', 'spawn_chance', 'avg_spawns', 'spawn_time',
#        'multipliers', 'weaknesses', 'next_evolution', 'prev_evolution'],
#       dtype='object')

# %%
len(df)
# Out:
# 151

# %%
for i in range(1, len(df)+1):

# %%
unique_values_in_type = set()

# %%
for val in df["type"]:
    for i in val:
        unique_values_in_type.add(i)
unique_values_in_type
# Out:
# {'B',
#  'Bug',
#  'D',
#  'Dragon',
#  'E',
#  'Electric',
#  'F',
#  'Fighting',
#  'Fire',
#  'Flying',
#  'G',
#  'Ghost',
#  'Grass',
#  'Ground',
#  'I',
#  'Ice',
#  'N',
#  'Normal',
#  'P',
#  'Poison',
#  'Psychic',
#  'R',
#  'Rock',
#  'W',
#  'Water',
#  'a',
#  'c',
#  'd',
#  'e',
#  'g',
#  'h',
#  'i',
#  'k',
#  'l',
#  'm',
#  'n',
#  'o',
#  'r',
#  's',
#  't',
#  'u',
#  'y'}

# %% [markdown]
# -------------------------------

# %%
import pandas as pd
Link = "https://data.nasa.gov/resource/y77d-th95.json"
data = pd.read_json(Link, orient = "columns")
data.head()
# Out:
#        name   id nametype     recclass      mass  fall
# 0    Aachen    1    Valid           L5      21.0  Fell  \
# 1    Aarhus    2    Valid           H6     720.0  Fell
# 2      Abee    6    Valid          EH4  107000.0  Fell
# 3  Acapulco   10    Valid  Acapulcoite    1914.0  Fell
# 4   Achiras  370    Valid           L6     780.0  Fell
#
#                       year    reclat    reclong
# 0  1880-01-01T00:00:00.000  50.77500    6.08333  \
# 1  1951-01-01T00:00:00.000  56.18333   10.23333
# 2  1952-01-01T00:00:00.000  54.21667 -113.00000
# 3  1976-01-01T00:00:00.000  16.88333  -99.90000
# 4  1902-01-01T00:00:00.000 -33.16667  -64.95000
#
#                                          geolocation
# 0  {'type': 'Point', 'coordinates': [6.08333, 50....  \
# 1  {'type': 'Point', 'coordinates': [10.23333, 56...
# 2  {'type': 'Point', 'coordinates': [-113, 54.216...
# 3  {'type': 'Point', 'coordinates': [-99.9, 16.88...
# 4  {'type': 'Point', 'coordinates': [-64.95, -33....
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         1000 non-null   object
#  1   id                           1000 non-null   int64
#  2   nametype                     1000 non-null   object
#  3   recclass                     1000 non-null   object
#  4   mass                         972 non-null    float64
#  5   fall                         1000 non-null   object
#  6   year                         999 non-null    object
#  7   reclat                       988 non-null    float64
#  8   reclong                      988 non-null    float64
#  9   geolocation                  988 non-null    object
#  10  :@computed_region_cbhk_fwbd  133 non-null    float64
#  11  :@computed_region_nnqa_25f4  134 non-null    float64
# dtypes: float64(5), int64(1), object(6)
# ...

# %%
data["year"] = data['year'].str[:4]

# %%
data.head()
# Out:
#        name   id nametype     recclass      mass  fall  year    reclat
# 0    Aachen    1    Valid           L5      21.0  Fell  1880  50.77500  \
# 1    Aarhus    2    Valid           H6     720.0  Fell  1951  56.18333
# 2      Abee    6    Valid          EH4  107000.0  Fell  1952  54.21667
# 3  Acapulco   10    Valid  Acapulcoite    1914.0  Fell  1976  16.88333
# 4   Achiras  370    Valid           L6     780.0  Fell  1902 -33.16667
#
#      reclong                                        geolocation
# 0    6.08333  {'type': 'Point', 'coordinates': [6.08333, 50....  \
# 1   10.23333  {'type': 'Point', 'coordinates': [10.23333, 56...
# 2 -113.00000  {'type': 'Point', 'coordinates': [-113, 54.216...
# 3  -99.90000  {'type': 'Point', 'coordinates': [-99.9, 16.88...
# 4  -64.95000  {'type': 'Point', 'coordinates': [-64.95, -33....
#
#    :@computed_region_cbhk_fwbd  :@computed_region_nnqa_25f4
# 0                          NaN                          NaN
# ...

# %%
len(data)
# Out:
# 1000

# %%
dummy_data = data

# %%
data[data["geolocation"].notnull()].apply(lambda x: x['coordinates'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx:155, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index_class_helper.pxi:70, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'coordinates'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[107], line 1
# ----> 1 data[data["geolocation"].notnull()].apply(lambda x: x['coordinates'])
#
# ...

# %%
data[data["geolocation"].notnull()] = data[data["geolocation"].notnull()].apply(lambda x: x['coordinates'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx:155, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index_class_helper.pxi:70, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'coordinates'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[105], line 1
# ...

# %%
data["geolocation"]["coordinates"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 data["geolocation"]["coordinates"]
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/series.py:1012, in Series.__getitem__(self, key)
#    1009     return self._values[key]
#    1011 elif key_is_scalar:
# -> 1012     return self._get_value(key)
#    1014 if is_hashable(key):
#    1015     # Otherwise index.get_value will raise InvalidIndexError
#    1016     try:
#    1017         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/series.py:1121, in Series._get_value(self, label, takeable)
#    1118     return self._values[label]
#    1120 # Similar to Index.get_value, but we do not fall back to positional
# -> 1121 loc = self.index.get_loc(label)
#    1123 if is_integer(loc):
#    1124     return self._values[loc]
# ...

# %%
# data[data['geolocation'].isnull()]
# Out:
#                      name     id nametype    recclass    mass   fall  year
# 147             Bulls Run   5163    Valid       Iron?  2250.0   Fell  1964  \
# 208               Clohars   5383    Valid          L4    48.6   Fell  1822
# 409              Jalanash  12068    Valid    Ureilite   700.0   Fell  1990
# 414              Jemlapur  12079    Valid          L6   450.0   Fell  1901
# 520   Cumulus Hills 04075  32531    Valid   Pallasite     9.6  Found  2003
# 586          Maria Linden  15418    Valid          L4   114.0   Fell  1925
# 681                 Natal  16923    Valid  Stone-uncl     1.4   Fell  1973
# 694            Niger (L6)  16974    Valid          L6     3.3   Fell  1967
# 695           Niger (LL6)  16975    Valid         LL6     3.3   Fell  1967
# 757  Dominion Range 03239  32591    Valid          L6    69.5  Found  2002
# 804  Dominion Range 03240  32592    Valid         LL5   290.9  Found  2002
# ...

# %%
data["geolocation"][0]["coordinates"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 data["geolocation"][0]["coordinates"]
#
# TypeError: list indices must be integers or slices, not str

# %%
for i in range(len(data)):
    data["geolocation"] = data["geolocation"][i]["coordinates"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[66], line 2
#       1 for i in range(len(data)):
# ----> 2     data["geolocation"] = data["geolocation"][i]["coordinates"]
#
# TypeError: list indices must be integers or slices, not str

# %%
for i in range(len(data)):
    if data["geolocation"][i].isnull():
        continue
    else:
        data["geolocation"] = data["geolocation"][i]["coordinates"]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[93], line 2
#       1 for i in range(len(data)):
# ----> 2     if data["geolocation"][i].isnull():
#       3         continue
#       4     else:
#
# AttributeError: 'dict' object has no attribute 'isnull'

# %%
for i in range(len(data)):
    if pd.isnull(data["geolocation"][i]):
        continue
    else:
        data["geolocation"][i] = data["geolocation"][i]["coordinates"]
# Out:
# /tmp/ipykernel_4365/3036510151.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["geolocation"][i] = data["geolocation"][i]["coordinates"]
# /tmp/ipykernel_4365/3036510151.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["geolocation"][i] = data["geolocation"][i]["coordinates"]
# /tmp/ipykernel_4365/3036510151.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
data.tail()
# Out:
#           name     id nametype               recclass     mass  fall  year
# 995   Tirupati  24009    Valid                     H6    230.0  Fell  1934  \
# 996    Tissint  54823    Valid  Martian (shergottite)   7000.0  Fell  2011
# 997      Tjabe  24011    Valid                     H6  20000.0  Fell  1869
# 998   Tjerebon  24012    Valid                     L5  16500.0  Fell  1922
# 999  Tomakovka  24019    Valid                    LL6    600.0  Fell  1905
#
#        reclat    reclong            geolocation
# 995  13.63333   79.41667   [79.41667, 13.63333]
# 996  29.48195   -7.61123   [-7.61123, 29.48195]
# 997  -7.08333  111.53333  [111.53333, -7.08333]
# 998  -6.66667  106.58333  [106.58333, -6.66667]
# 999  47.85000   34.76667      [34.76667, 47.85]

# %%
for i in range(0,len(df)+1):
        df['geolocation'].iloc[i]['coordinates'] = [ int(j) for j in df['geolocation'].iloc[i]['coordinates']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'geolocation'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
# data = data.drop(labels=[":@computed_region_nnqa_25f4", ":@computed_region_cbhk_fwbd"], axis=1)
# data.head()
# Out:
#        name   id nametype     recclass      mass  fall  year    reclat
# 0    Aachen    1    Valid           L5      21.0  Fell  1880  50.77500  \
# 1    Aarhus    2    Valid           H6     720.0  Fell  1951  56.18333
# 2      Abee    6    Valid          EH4  107000.0  Fell  1952  54.21667
# 3  Acapulco   10    Valid  Acapulcoite    1914.0  Fell  1976  16.88333
# 4   Achiras  370    Valid           L6     780.0  Fell  1902 -33.16667
#
#      reclong                                        geolocation
# 0    6.08333  {'type': 'Point', 'coordinates': [6.08333, 50....
# 1   10.23333  {'type': 'Point', 'coordinates': [10.23333, 56...
# 2 -113.00000  {'type': 'Point', 'coordinates': [-113, 54.216...
# 3  -99.90000  {'type': 'Point', 'coordinates': [-99.9, 16.88...
# 4  -64.95000  {'type': 'Point', 'coordinates': [-64.95, -33....

# %%
# conrdinates = data['geolocation'].apply(lambda x: x['coordinates'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 conrdinates = data['geolocation'].apply(lambda x: x['coordinates'])
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/series.py:4631, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4521 def apply(
#    4522     self,
#    4523     func: AggFuncType,
#    (...)
#    4526     **kwargs,
#    4527 ) -> DataFrame | Series:
#    4528     """
#    4529     Invoke function on values of Series.
#    4530
#    (...)
#    4629     dtype: float64
#    4630     """
# -> 4631     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/apply.py:1025, in SeriesApply.apply(self)
#    1022     return self.apply_str()
#    1024 # self.f is Callable
# -> 1025 return self.apply_standard()
#
# ...

# %%
import pandas as pd

# Sample DataFrame
data = {'coordinates_column': [{'type': 'Point', 'coordinates': [-64.95, -33.5]},
                              {'type': 'Point', 'coordinates': [-65.1, -33.7]},
                              {'type': 'Point', 'coordinates': [-64.8, -33.2]}]}
df = pd.DataFrame(data)

# Extract list of coordinates
coordinates_list = df['coordinates_column'].apply(lambda x: x['coordinates'])

print(coordinates_list)
# Out:
# 0    [-64.95, -33.5]
# 1     [-65.1, -33.7]
# 2     [-64.8, -33.2]
# Name: coordinates_column, dtype: object

# %% [markdown]
# ---------------------------

# %%
import requests
import pandas as pd

# Make a request to the API
url = r'http://api.tvmaze.com/singlesearch/shows?q=westworld&embed=episodes'
response = requests.get(url)

# Convert the response to a JSON object
json_data = response.json()
json_data
# Out:
# {'id': 1371,
#  'url': 'https://www.tvmaze.com/shows/1371/westworld',
#  'name': 'Westworld',
#  'type': 'Scripted',
#  'language': 'English',
#  'genres': ['Drama', 'Science-Fiction', 'Western'],
#  'status': 'Ended',
#  'runtime': 60,
#  'averageRuntime': 63,
#  'premiered': '2016-10-02',
#  'ended': '2022-08-14',
#  'officialSite': 'http://www.hbo.com/westworld',
#  'schedule': {'time': '21:00', 'days': ['Sunday']},
#  'rating': {'average': 8.2},
#  'weight': 99,
#  'network': {'id': 8,
#   'name': 'HBO',
#   'country': {'name': 'United States',
#    'code': 'US',
#    'timezone': 'America/New_York'},
#   'officialSite': 'https://www.hbo.com/'},
#  'webChannel': None,
#  'dvdCountry': None,
#  'externals': {'tvrage': 37537, 'thetvdb': 296762, 'imdb': 'tt0475784'},
#  'image': {'medium': 'https://static.tvmaze.com/uploads/images/medium_portrait/445/1113927.jpg',
#   'original': 'https://static.tvmaze.com/uploads/images/original_untouched/445/1113927.jpg'},
# ...

# %%
df = pd.read_json(json_data)
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[129], line 1
# ----> 1 df = pd.read_json(json_data)
#       2 df
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/json/_json.py:760, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     757 if convert_axes is None and orient != "table":
#     758     convert_axes = True
# --> 760 json_reader = JsonReader(
#     761     path_or_buf,
#     762     orient=orient,
#     763     typ=typ,
#     764     dtype=dtype,
#     765     convert_axes=convert_axes,
#     766     convert_dates=convert_dates,
#     767     keep_default_dates=keep_default_dates,
#     768     precise_float=precise_float,
#     769     date_unit=date_unit,
# ...

# %%
for item in json_data.items():
    print(item)
# Out:
# ('id', 1371)
# ('url', 'https://www.tvmaze.com/shows/1371/westworld')
# ('name', 'Westworld')
# ('type', 'Scripted')
# ('language', 'English')
# ('genres', ['Drama', 'Science-Fiction', 'Western'])
# ('status', 'Ended')
# ('runtime', 60)
# ('averageRuntime', 63)
# ('premiered', '2016-10-02')
# ('ended', '2022-08-14')
# ('officialSite', 'http://www.hbo.com/westworld')
# ('schedule', {'time': '21:00', 'days': ['Sunday']})
# ('rating', {'average': 8.2})
# ('weight', 99)
# ('network', {'id': 8, 'name': 'HBO', 'country': {'name': 'United States', 'code': 'US', 'timezone': 'America/New_York'}, 'officialSite': 'https://www.hbo.com/'})
# ('webChannel', None)
# ('dvdCountry', None)
# ('externals', {'tvrage': 37537, 'thetvdb': 296762, 'imdb': 'tt0475784'})
# ('image', {'medium': 'https://static.tvmaze.com/uploads/images/medium_portrait/445/1113927.jpg', 'original': 'https://static.tvmaze.com/uploads/images/original_untouched/445/1113927.jpg'})
# ...

# %%
type(json_data)
# Out:
# dict

# %%
pd.DataFrame([json_data])
# Out:
#      id                                          url       name      type
# 0  1371  https://www.tvmaze.com/shows/1371/westworld  Westworld  Scripted  \
#
#   language                             genres status  runtime  averageRuntime
# 0  English  [Drama, Science-Fiction, Western]  Ended       60              63  \
#
#     premiered  ... weight                                            network
# 0  2016-10-02  ...     99  {'id': 8, 'name': 'HBO', 'country': {'name': '...  \
#
#   webChannel dvdCountry                                          externals
# 0       None       None  {'tvrage': 37537, 'thetvdb': 296762, 'imdb': '...  \
#
#                                                image
# 0  {'medium': 'https://static.tvmaze.com/uploads/...  \
#
#                                              summary     updated
# 0  <p><b>Westworld</b> is a dark odyssey about th...  1675592943  \
#
#                                               _links
# ...

# %%
pd.json_normalize(json_data, )
# Out:
#      id                                          url       name      type
# 0  1371  https://www.tvmaze.com/shows/1371/westworld  Westworld  Scripted  \
#
#   language                             genres status  runtime  averageRuntime
# 0  English  [Drama, Science-Fiction, Western]  Ended       60              63  \
#
#     premiered  ... network.country.timezone  network.officialSite
# 0  2016-10-02  ...         America/New_York  https://www.hbo.com/  \
#
#    externals.tvrage externals.thetvdb externals.imdb
# 0             37537            296762      tt0475784  \
#
#                                         image.medium
# 0  https://static.tvmaze.com/uploads/images/mediu...  \
#
#                                       image.original
# 0  https://static.tvmaze.com/uploads/images/origi...  \
#
#                     _links.self.href              _links.previousepisode.href
# 0  https://api.tvmaze.com/shows/1371  https://api.tvmaze.com/episodes/2326661  \
#
# ...

# %%
import requests
import json
from bs4 import BeautifulSoup

def download_and_extract_data(url):
    # Download the data from the API link
    response = requests.get(url)
    data = response.json()

    # Extract the required data attributes
    show_id = data['id']
    show_url = data['url']
    show_name = data['name']
    episodes = data['_embedded']['episodes']
    
    episode_list = []
    for episode in episodes:
        episode_season = episode['season']
        episode_number = episode['number']
        episode_type = episode['type']
        episode_airdate = episode['airdate']
        episode_airtime = episode['airtime']
        episode_runtime = episode['runtime']
        episode_rating = episode['rating']['average']
        episode_summary = BeautifulSoup(episode['summary'], 'html.parser').get_text()
        episode_image_medium = episode['image']['medium']
        episode_image_original = episode['image']['original']
        
        episode_info = {
            'ID': show_id,
            'URL': show_url,
            'Name': show_name,
            'Season': episode_season,
            'Number': episode_number,
            'Type': episode_type,
            'Airdate': episode_airdate,
            'Airtime': episode_airtime,
            'Runtime': episode_runtime,
            'Rating': episode_rating,
            'Summary': episode_summary,
            'Medium Image': episode_image_medium,
            'Original Image': episode_image_original
        }
        episode_list.append(episode_info)

    # Print the extracted data attributes with proper formatting
    print("Show ID:", show_id)
    print("Show URL:", show_url)
    print("Show Name:", show_name)
    print("\nEpisodes:")
    for episode in episode_list:
        print("ID:", episode['ID'])
        print("URL:", episode['URL'])
        print("Name:", episode['Name'])
        print("Season:", episode['Season'])
        print("Number:", episode['Number'])
        print("Type:", episode['Type'])
        print("Airdate:", episode['Airdate'])
        print("Airtime:", episode['Airtime'])
        print("Runtime:", episode['Runtime'])
        print("Rating:", episode['Rating'])
        print("Summary:", episode['Summary'])
        print("Medium Image:", episode['Medium Image'])
        print("Original Image:", episode['Original Image'])
        print()

# Provide the API link to download the data
url = 'http://api.tvmaze.com/singlesearch/shows?q=westworld&embed=episodes'

# Call the function to download and extract the data attributes
download_and_extract_data(url)
# Out:
# Show ID: 1371
# Show URL: https://www.tvmaze.com/shows/1371/westworld
# Show Name: Westworld
#
# Episodes:
# ID: 1371
# URL: https://www.tvmaze.com/shows/1371/westworld
# Name: Westworld
# Season: 1
# Number: 1
# Type: regular
# Airdate: 2016-10-02
# Airtime: 21:00
# Runtime: 68
# Rating: 8
# Summary: A woman named Dolores is a free spirit in the Old West... and unaware that she's actually an android, programmed to entertain rich guests seeking to act out their fantasies in an idealized vision of the 1880s. However, the people in charge soon realize that their androids are acting in ways that they didn't anticipate.
# Medium Image: https://static.tvmaze.com/uploads/images/medium_landscape/78/195475.jpg
# Original Image: https://static.tvmaze.com/uploads/images/original_untouched/78/195475.jpg
#
# ID: 1371
# URL: https://www.tvmaze.com/shows/1371/westworld
# Name: Westworld
# Season: 1
# Number: 2
# Type: regular
# Airdate: 2016-10-09
# Airtime: 21:00
# Runtime: 60
# Rating: 7.7
# ...

# %%
import pandas as pd

df = pd.read_excel("/home/omkar/Omkar Pawar/Data Science/Placement Assignment Omkar Pawar/pokemon.xlsx")

# %%
df.head(3)
# Out:
#    id  num       name                                               img
# 0   1    1  Bulbasaur  http://www.serebii.net/pokemongo/pokemon/001.png  \
# 1   2    2    Ivysaur  http://www.serebii.net/pokemongo/pokemon/002.png
# 2   3    3   Venusaur  http://www.serebii.net/pokemongo/pokemon/003.png
#
#                   type  height    weight            candy  candy_count
# 0  ['Grass', 'Poison']  0.71 m    6.9 kg  Bulbasaur Candy         25.0  \
# 1  ['Grass', 'Poison']  0.99 m   13.0 kg  Bulbasaur Candy        100.0
# 2  ['Grass', 'Poison']  2.01 m  100.0 kg  Bulbasaur Candy          NaN
#
#            egg  spawn_chance  avg_spawns spawn_time multipliers
# 0         2 km         0.690        69.0      20:00      [1.58]  \
# 1  Not in Eggs         0.042         4.2      07:00  [1.2, 1.6]
# 2  Not in Eggs         0.017         1.7      11:30         NaN
#
#                              weaknesses
# 0  ['Fire', 'Ice', 'Flying', 'Psychic']  \
# 1  ['Fire', 'Ice', 'Flying', 'Psychic']
# ...
